# %% [markdown]
# <a href="https://colab.research.google.com/github/kevidn/Basic-Pandas/blob/main/BelajarPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
data = {
    'Name': ['Kevin', 'Dzaky', 'Hendra', 'Tama'],
    'Age': [23, 45, 46, 99]
}

df1 = pd.DataFrame(data)
df1
# Out:
#      Name  Age
# 0   Kevin   23
# 1   Dzaky   45
# 2  Hendra   46
# 3    Tama   99

# %%
pip install scipy

# %%
import numpy as np
import pandas as pd

jumlah_kucing = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
jumlah_kucing_series = pd.Series(jumlah_kucing)
jumlah_kucing_series.std()
# Out:
# 0.9486832980505139

# %%
import pandas as pd

sample_data = {
    'name': ['John', 'Alia', 'Ananya', 'Steve', 'Ben'],
    'age': [24, 22, 23, 25, 28],
    'communication_skill_score': [85, 70, 75, 90, 90],
    'quantitative_skill_score': [80, 90, 80, 75, 70]
}

df = pd.DataFrame(sample_data)

df.corr(numeric_only=True)
# Out:
#                                 age  communication_skill_score  \
# age                        1.000000                   0.848855
# communication_skill_score  0.848855                   1.000000
# quantitative_skill_score  -0.922489                  -0.890724
#
#                            quantitative_skill_score
# age                                       -0.922489
# communication_skill_score                 -0.890724
# quantitative_skill_score                   1.000000

# %%
import pandas as pd

sample_data = {
    'name': ['John', 'Alia', 'Ananya', 'Steve', 'Ben'],
    'age': [24, 22, 23, 25, 28],
    'communication_skill_score': [85, 70, 75, 90, 90],
    'quantitative_skill_score': [80, 90, 80, 75, 70]
}

df = pd.DataFrame(sample_data)

df.cov(numeric_only=True)
# Out:
#                              age  communication_skill_score  \
# age                         5.30                      17.75
# communication_skill_score  17.75                      82.50
# quantitative_skill_score  -15.75                     -60.00
#
#                            quantitative_skill_score
# age                                          -15.75
# communication_skill_score                    -60.00
# quantitative_skill_score                      55.00

# %%
import pandas as pd

url = "https://id.wikipedia.org/wiki/Daftar_anggota_JKT48"
data2 = pd.read_html(url)[2]
df2 = data2.drop([0,1])

# %%
df2
# Out:
#    Daftar siswi pelatihan (Untuk menampilkan tabel di bawah ini, silakan tekan tombol "kembangkan")  \
# 2                                 Alya Amanda Fatihah
# 3                           Anindya Ramadhani Purnomo
# 4                                 Cathleen Hana Nixie
# 5                                   Celline Thefannie
# 6                               Chelsea Davina Norman
# 7                                    Cynthia Yaputera
# 8                                        Dena Natalia
# 9                                        Desy Natalia
# 10                         Gendis Mayrannisa Setiawan
# 11                           Grace Octaviani Tanujaya
# 12                          Greesella Sophina Adhalia
# 13                           Jeane Victoria Kurniawan
# 14                          Michelle Alexandra Suandi
#
#    Daftar siswi pelatihan (Untuk menampilkan tabel di bawah ini, silakan tekan tombol "kembangkan").1  \
# 2                                                Alya
# ...
